# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data_complete_index= school_data_complete.set_index ("school_name")
school_data_complete_index
# Out:
#                     Student ID       student_name gender grade  reading_score  \
# school_name
# Huang High School            0       Paul Bradley      M   9th             66
# Huang High School            1       Victor Smith      M  12th             94
# Huang High School            2    Kevin Rodriguez      M  12th             90
# Huang High School            3  Dr. Richard Scott      M  12th             67
# Huang High School            4         Bonnie Ray      F   9th             97
# ...                        ...                ...    ...   ...            ...
# Thomas High School       39165       Donna Howard      F  12th             99
# Thomas High School       39166          Dawn Bell      F  10th             95
# Thomas High School       39167     Rebecca Tanner      F   9th             73
# Thomas High School       39168       Desiree Kidd      F  10th             99
# Thomas High School       39169    Carolyn Jackson      F  11th             95
#
# ...

# %%
student_data_count = school_data_complete_index[school_data_complete_index["size"].notana()]
student_data_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-23fd759eee89> in <module>
# ----> 1 student_data_count = school_data_complete_index[school_data_complete_index["size"].notana()]
#       2 student_data_count
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'notana'

# %%
reading_over_70 = school_data_complete_index.loc[school_data_complete_index["reading_score"] >= 70]
reading_over_70
# Out:
#                     Student ID     student_name gender grade  reading_score  \
# school_name
# Huang High School            1     Victor Smith      M  12th             94
# Huang High School            2  Kevin Rodriguez      M  12th             90
# Huang High School            4       Bonnie Ray      F   9th             97
# Huang High School            5    Bryan Miranda      M   9th             94
# Huang High School            6    Sheena Carter      F  11th             82
# ...                        ...              ...    ...   ...            ...
# Thomas High School       39165     Donna Howard      F  12th             99
# Thomas High School       39166        Dawn Bell      F  10th             95
# Thomas High School       39167   Rebecca Tanner      F   9th             73
# Thomas High School       39168     Desiree Kidd      F  10th             99
# Thomas High School       39169  Carolyn Jackson      F  11th             95
#
# ...

# %%
reading_over_70_group = reading_over_70.groupby("school_name")
reading_over_70_group.count().head(10)
# Out:
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4077          4077    4077   4077           4077
# Cabrera High School          1803          1803    1803   1803           1803
# Figueroa High School         2381          2381    2381   2381           2381
# Ford High School             2172          2172    2172   2172           2172
# Griffin High School          1426          1426    1426   1426           1426
# Hernandez High School        3748          3748    3748   3748           3748
# Holden High School            411           411     411    411            411
# Huang High School            2372          2372    2372   2372           2372
# Johnson High School          3867          3867    3867   3867           3867
# Pena High School              923           923     923    923            923
#
#                        math_score  School ID  type  size  budget
# school_name
# ...

# %%
reading_score_70_unique = reading_over_70_group["reading_score"]
reading_score_70_unique.count().head(10)
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Name: reading_score, dtype: int64

# %%
student_count_unique = school_data_complete_index["size"]
# Out:
# school_name
# Huang High School     2917
# Huang High School     2917
# Huang High School     2917
# Huang High School     2917
# Huang High School     2917
#                       ...
# Thomas High School    1635
# Thomas High School    1635
# Thomas High School    1635
# Thomas High School    1635
# Thomas High School    1635
# Name: size, Length: 39170, dtype: int64

# %%
student_count_for_pass_grade = student_count_unique.drop_duplicates()

# %%
total_pass_count = student_count_for_pass_grade
total_pass_count
# Out:
# school_name
# Huang High School        2917
# Figueroa High School     2949
# Shelton High School      1761
# Hernandez High School    4635
# Griffin High School      1468
# Wilson High School       2283
# Cabrera High School      1858
# Bailey High School       4976
# Holden High School        427
# Pena High School          962
# Wright High School       1800
# Rodriguez High School    3999
# Johnson High School      4761
# Ford High School         2739
# Thomas High School       1635
# Name: size, dtype: int64

# %%
reading_pass_group_percent = reading_pass_count_school
reading_pass_group_percent
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: reading_score, dtype: int64

# %%
student_total_count = student_count.unique()
student_total_count
# Out:
# array([2917, 2949, 1761, 4635, 1468, 2283, 1858, 4976,  427,  962, 1800,
#        3999, 4761, 2739, 1635], dtype=int64)

# %%
summarydf = pd.DataFrame({"School Type": reading_pass_group_percent
                                                         })
summarydf
# Out:
#                        School Type
# school_name
# Bailey High School            4077
# Cabrera High School           1803
# Figueroa High School          2381
# Ford High School              2172
# Griffin High School           1426
# Hernandez High School         3748
# Holden High School             411
# Huang High School             2372
# Johnson High School           3867
# Pena High School               923
# Rodriguez High School         3208
# Shelton High School           1688
# Thomas High School            1591
# Wilson High School            2204
# Wright High School            1739
